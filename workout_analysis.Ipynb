# %%
import gym_data_analysis.analysis as analysis
import yaml
import pandas as pd
import ipywidgets as widgets

# %%
#Preprocessing
config = None
with open("config.yaml") as f:
    config = yaml.safe_load(f)
raw_df = pd.read_csv(config["input_data"], delimiter=";", parse_dates=['Date'])
raw_df['Workout Duration'] = raw_df['Workout Duration'].apply(analysis.parse_duration)
# convert weight to kg
# convert distance to metres
raw_df = raw_df.drop(columns=["Weight Unit", "RPE", "Distance", "Distance Unit", "Seconds", "Notes", "Workout Notes"])

# Should I create a new column for this? Should the df only include essential data ?
raw_df["Volume"] = raw_df["Reps"] * raw_df["Weight"]

raw_df
# Out:
#                     Date           Workout Name           Exercise Name  \
# 0    2023-07-30 16:49:28                   Arms  Bench Press (Dumbbell)
# 1    2023-07-30 16:49:28                   Arms  Bench Press (Dumbbell)
# 2    2023-07-30 16:49:28                   Arms  Bench Press (Dumbbell)
# 3    2023-07-30 16:49:28                   Arms   Bicep Curl (Dumbbell)
# 4    2023-07-30 16:49:28                   Arms   Bicep Curl (Dumbbell)
# ...                  ...                    ...                     ...
# 3192 2024-06-05 16:57:37  Pull 1 (back, biceps)  Hammer Curl (Dumbbell)
# 3193 2024-06-05 16:57:37  Pull 1 (back, biceps)  Hammer Curl (Dumbbell)
# 3194 2024-06-05 16:57:37  Pull 1 (back, biceps)                Deadhang
# 3195 2024-06-05 16:57:37  Pull 1 (back, biceps)                Deadhang
# 3196 2024-06-05 16:57:37  Pull 1 (back, biceps)                Deadhang
#
#       Set Order  Weight  Reps  Workout Duration  Volume
# ...

# %%
grouped_workout_df = raw_df.groupby(["Date", "Workout Name", "Workout Duration"]).agg({"Volume": "sum", "Reps": "sum"}).reset_index()
grouped_workout_df
# Out:
#                    Date                        Workout Name  Workout Duration  \
# 0   2023-07-30 16:49:28                                Arms                44
# 1   2023-08-01 16:16:08                        Back and abs                43
# 2   2023-08-03 15:08:07                                Legs                50
# 3   2023-08-05 13:07:31                                Arms                50
# 4   2023-08-06 09:01:55                        Back and abs                53
# ..                  ...                                 ...               ...
# 187 2024-05-28 16:02:00  Push 2 (chest, shoulders, triceps)                72
# 188 2024-06-01 09:28:04               Pull 2 (back, biceps)                63
# 189 2024-06-02 18:50:40                       Legs & Core 2                63
# 190 2024-06-04 19:14:52   Push 1 (chest, tricep, shoulders)                59
# 191 2024-06-05 16:57:37               Pull 1 (back, biceps)                51
#
#      Volume   Reps
# ...

# %%
analysis.plot_heatmap(grouped_workout_df["Workout Duration"].values, grouped_workout_df["Date"].values)
# Out:
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.

# %%
# display workout frequency
analysis.plot_weekly_workouts(grouped_workout_df)

# %%
analysis.plot_daily_workouts(grouped_workout_df)

# %%
analysis.plot_hourly_workouts(grouped_workout_df)

# %%
analysis.plot_workouts_every_minute(grouped_workout_df)

# %%
analysis.plot_workout_types(grouped_workout_df)

# %%
import matplotlib.pyplot as plt
# With drop down to filter 
workout_names = list(raw_df["Workout Name"].value_counts().index)
workout_names.insert(0,"all")

def choose_filter(x):
    filtered_df = grouped_workout_df[grouped_workout_df["Workout Name"] == x].copy()
    if x == "all":
        filtered_df = grouped_workout_df
    analysis.plot_heatmap(filtered_df["Workout Duration"].values, filtered_df["Date"].values)
    analysis.plot_daily_workouts(filtered_df)
    analysis.plot_workouts_every_minute(filtered_df)

widgets.interact(choose_filter, x=workout_names)
# Out:
# interactive(children=(Dropdown(description='x', options=('all', 'Arms', 'Pull 1 (back, biceps)', 'Push 2 (ches…
# <function __main__.choose_filter(x)>
